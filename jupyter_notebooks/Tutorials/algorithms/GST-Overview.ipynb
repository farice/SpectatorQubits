# %% [markdown]
# # An overview of Gate Set Tomography

# %% [markdown]
# The `pygsti` package provides multiple levels of abstraction over the core Gate Set Tomography (GST) algorithms.  This tutorial will show you how to run Gate Set Tomography on some simulated (generated) data, hopefully giving you an overall sense of what it takes (and how easy it is!) to run GST.  For more details and options for running GST, see the [GST circuits tutorial](../objects/advanced/GSTCircuitConstruction.ipynb) and the [tutorial covering the different pyGSTi functions for running GST](GST-Drivers.ipynb).
#
# To run GST, we need three inputs:
# 1. a "**target model**" which describes the desired, or ideal, operations we want our experimental hardware to perform.  In the example below, we use one of pyGSTi's "standard" models (see the [tutorial on standard modules](objects/advanced/StandardModules.ipynb)) - which acts on a single qubit with the following operations:
#     - three gates: the identity, and $\pi/2$ rotations around the $x$- and $y$-axes.
#     - a single state preparation in the $|0\rangle$ state.
#     - a 2-outcome measurement with the label "0" associated with measuring $|0\rangle$ and "1" with measuring $|1\rangle$.
#
# 2. a list of circuits tailored to the target model; essentially a list of what experiments we need to run.  Using a standard model makes things especially straightforward here, since the building blocks, called *germ* and *fiducial* circuits, needed to make good GST circuits have already been computed (see the [tutorial on GST circuits](../objects/advanced/GSTCircuitConstruction.ipynb)).
#
# 3. data, in the form of experimental outcome counts, for each of the required sequences.  In this example we'll generate "fake" or "simulated" data from a depolarized version of our ideal model.  For more information about `DataSet` objects, see the [tutorial on DataSets](../objects/DataSet.ipynb).

# %%
#Make print statements compatible with Python 2 and 3
from __future__ import print_function

#Import the pygsti module (always do this) and the standard XYI model
import pygsti
from pygsti.construction import std1Q_XYI

# 1) get the target Model
target_model = std1Q_XYI.target_model()

# 2) get the building blocks needed to specify which operation sequences are needed
prep_fiducials, meas_fiducials = std1Q_XYI.prepStrs, std1Q_XYI.effectStrs
germs = std1Q_XYI.germs
maxLengths = [1,2,4,8,16,32] # roughly gives the length of the sequences used by GST

# 3) generate "fake" data from a depolarized version of target_model
mdl_datagen = target_model.depolarize(op_noise=0.01, spam_noise=0.001)
listOfExperiments = pygsti.construction.make_lsgst_experiment_list(
    target_model, prep_fiducials, meas_fiducials, germs, maxLengths)
ds = pygsti.construction.generate_fake_data(mdl_datagen, listOfExperiments, nSamples=1000,
                                            sampleError="binomial", seed=1234)

#Note: from listOfExperiments we can also create an empty dataset file
# which has columns of zeros where actual data should go. 
pygsti.io.write_empty_dataset("../tutorial_files/GettingStartedDataTemplate.txt", listOfExperiments,
                              "## Columns = 0 count, 1 count")
# After replacing the zeros with actual data, the data set can be 
# loaded back into pyGSTi using the line below and used in the rest
# of this tutorial. 
#ds = pygsti.io.load_dataset("tutorial_files/GettingStartedDataTemplate.txt")
# Out:
# WARNING:root:
# Welcome to pygsti version 0.9.7!
# There have been some major changes between this version and 0.9.6 - ones that break backward compatibility.  If you're trying to run an old script and nothing works, DON'T PANIC; we've tried to make the transition easy.  More often then not, you can just run `pyGSTi/scripts/upgrade2v0.9.7.py` on your old script or notebook files and you'll be up and running again.  For more information, see the pyGSTi FAQ.ipynb.
#
# If this warning annoys you run:
#   `export PYGSTI_BACKCOMPAT_WARNING=0` from the command line or
#   `import os; os.environ['PYGSTI_BACKCOMPAT_WARNING'] = '0'` in a script or
#      notebook *before* importing pygsti and the the madness will stop.

# %% [markdown]
# Now that we have all of the inputs, we can run GST in a standard way using the `do_stdpractice_gst` function.  For more information about this and related functions, see the [GST methods tutorial](GST-Drivers.ipynb).  This returns a `pygsti.report.Results` object (see the [Results tutorial](../objects/advanced/Results.ipynb)), from which we can generate a report giving us a summary of the analysis.

# %%
#Run GST and create a report
results = pygsti.do_stdpractice_gst(ds, target_model, prep_fiducials, meas_fiducials, 
                                    germs, maxLengths, verbosity=3)

pygsti.report.create_standard_report(results, filename="../tutorial_files/gettingStartedReport",
                                    title="GST Overview Tutorial Example Report", verbosity=2)
# Out:
# -- Std Practice:  Iter 1 of 3  (TP) --:
#   --- Circuit Creation ---
#      1702 sequences created
#      Dataset has 1702 entries: 1702 utilized, 0 requested sequences were missing
#   --- LGST ---
#     Singular values of I_tilde (truncating to first 4 of 6) =
#     4.242865843377725
#     1.3900765589279662
#     1.3649838086380157
#     1.3472944816189396
#     0.04224890328547743
#     0.030139799998574607
#
#     Singular values of target I_tilde (truncating to first 4 of 6) =
#     4.242640687119285
#     1.4142135623730963
#     1.4142135623730958
#     1.4142135623730954
#     2.886142163912998e-16
#     1.8096566263435588e-16
#
#   --- Iterative MLGST: Iter 1 of 6  92 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 82.6143 (92 data params - 31 model params = expected mean of 61; p-value = 0.0341509)
#     Completed in 0.2s
#     2*Delta(log(L)) = 83.985
#     Iteration 1 took 0.2s
#
#   --- Iterative MLGST: Iter 2 of 6  168 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 146.374 (168 data params - 31 model params = expected mean of 137; p-value = 0.276283)
#     Completed in 0.2s
#     2*Delta(log(L)) = 148.841
#     Iteration 2 took 0.2s
#
#   --- Iterative MLGST: Iter 3 of 6  450 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 440.256 (450 data params - 31 model params = expected mean of 419; p-value = 0.228089)
#     Completed in 0.4s
#     2*Delta(log(L)) = 445.65
#     Iteration 3 took 0.4s
#
#   --- Iterative MLGST: Iter 4 of 6  862 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 891.038 (862 data params - 31 model params = expected mean of 831; p-value = 0.0728483)
#     Completed in 0.6s
#     2*Delta(log(L)) = 899.156
#     Iteration 4 took 0.6s
#
#   --- Iterative MLGST: Iter 5 of 6  1282 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 1308.88 (1282 data params - 31 model params = expected mean of 1251; p-value = 0.124451)
#     Completed in 0.8s
#     2*Delta(log(L)) = 1316.62
#     Iteration 5 took 0.9s
#
#   --- Iterative MLGST: Iter 6 of 6  1702 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 1715.06 (1702 data params - 31 model params = expected mean of 1671; p-value = 0.221499)
#     Completed in 1.4s
#     2*Delta(log(L)) = 1723.13
#     Iteration 6 took 1.5s
#
#     Switching to ML objective (last iteration)
#     --- MLGST ---
#       Maximum log(L) = 860.643 below upper bound of -2.63408e+06
#         2*Delta(log(L)) = 1721.29 (1702 data params - 31 model params = expected mean of 1671; p-value = 0.19139)
#       Completed in 1.2s
#     2*Delta(log(L)) = 1721.29
#     Final MLGST took 1.2s
#
#   Iterative MLGST Total Time: 4.9s
#   -- Performing 'single' gauge optimization on TP estimate --
# -- Std Practice:  Iter 2 of 3  (CPTP) --:
#   --- Circuit Creation ---
#      1702 sequences created
#      Dataset has 1702 entries: 1702 utilized, 0 requested sequences were missing
#   --- Iterative MLGST: Iter 1 of 6  92 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 7261.36 (92 data params - 29 model params = expected mean of 63; p-value = 0)
#     Completed in 14.2s
#     2*Delta(log(L)) = 9298.63
#     Iteration 1 took 14.2s
#
#   --- Iterative MLGST: Iter 2 of 6  168 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 14453 (168 data params - 29 model params = expected mean of 139; p-value = 0)
#     Completed in 3.8s
#     2*Delta(log(L)) = 18419.6
#     Iteration 2 took 3.8s
#
#   --- Iterative MLGST: Iter 3 of 6  450 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 51157.2 (450 data params - 30 model params = expected mean of 420; p-value = 0)
#     Completed in 4.3s
#     2*Delta(log(L)) = 64498
#     Iteration 3 took 4.3s
#
#   --- Iterative MLGST: Iter 4 of 6  862 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 106512 (862 data params - 29 model params = expected mean of 833; p-value = 0)
#     Completed in 5.1s
#     2*Delta(log(L)) = 132484
#     Iteration 4 took 5.2s
#
#   --- Iterative MLGST: Iter 5 of 6  1282 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 1325.74 (1282 data params - 31 model params = expected mean of 1251; p-value = 0.0696008)
#     Completed in 13.7s
#     2*Delta(log(L)) = 1333.43
#     Iteration 5 took 13.7s
#
#   --- Iterative MLGST: Iter 6 of 6  1702 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 1825.59 (1702 data params - 31 model params = expected mean of 1671; p-value = 0.00456429)
#     Completed in 6.1s
#     2*Delta(log(L)) = 1833.29
#     Iteration 6 took 6.1s
#
#     Switching to ML objective (last iteration)
#     --- MLGST ---
#       Maximum log(L) = 915.696 below upper bound of -2.63408e+06
#         2*Delta(log(L)) = 1831.39 (1702 data params - 31 model params = expected mean of 1671; p-value = 0.00344824)
#       Completed in 2.2s
#     2*Delta(log(L)) = 1831.39
#     Final MLGST took 2.2s
#
#   Iterative MLGST Total Time: 49.5s
#   --- Re-optimizing logl after robust data scaling ---
#     --- MLGST ---
#       Maximum log(L) = 915.696 below upper bound of -2.63408e+06
#         2*Delta(log(L)) = 1831.39 (1702 data params - 31 model params = expected mean of 1671; p-value = 0.00344824)
#       Completed in 0.6s
#   -- Performing 'single' gauge optimization on CPTP estimate --
#   -- Conveying 'single' gauge optimization to CPTP.Robust+ estimate --
# -- Std Practice:  Iter 3 of 3  (Target) --:
#   --- Circuit Creation ---
#      1702 sequences created
#      Dataset has 1702 entries: 1702 utilized, 0 requested sequences were missing
#   -- Performing 'single' gauge optimization on Target estimate --
# *** Creating workspace ***
# *** Generating switchboard ***
# Found standard clifford compilation from std1Q_XYI
# Found standard clifford compilation from std1Q_XYI
# Found standard clifford compilation from std1Q_XYI
# *** Generating tables ***
#   targetSpamBriefTable                          took 0.585863 seconds
#   targetGatesBoxTable                           took 0.727749 seconds
#   datasetOverviewTable                          took 0.081351 seconds
#   bestGatesetSpamParametersTable                took 0.001884 seconds
#   bestGatesetSpamBriefTable                     took 0.768566 seconds
#   bestGatesetSpamVsTargetTable                  took 0.124973 seconds
#   bestGatesetGaugeOptParamsTable                took 0.000979 seconds
#   bestGatesetGatesBoxTable                      took 0.761709 seconds
#   bestGatesetChoiEvalTable                      took 1.956742 seconds
#   bestGatesetDecompTable                        took 1.223383 seconds
#   bestGatesetEvalTable                          took 0.009592 seconds
#   bestGermsEvalTable                            took 0.116018 seconds
#   bestGatesetVsTargetTable                      took 0.4248 seconds
#   bestGatesVsTargetTable_gv                     took 0.361251 seconds
#   bestGatesVsTargetTable_gvgerms                took 0.576292 seconds
#   bestGatesVsTargetTable_gi                     took 0.021602 seconds
#   bestGatesVsTargetTable_gigerms                took 0.190009 seconds
#   bestGatesVsTargetTable_sum                    took 0.404932 seconds
#   bestGatesetErrGenBoxTable                     took 3.884003 seconds
#   metadataTable                                 took 0.001466 seconds
#   stdoutBlock                                   took 0.00084 seconds
#   profilerTable                                 took 0.001407 seconds
#   softwareEnvTable                              took 0.014358 seconds
#   exampleTable                                  took 0.093696 seconds
#   singleMetricTable_gv                          took 0.376689 seconds
#   singleMetricTable_gi                          took 0.023907 seconds
#   fiducialListTable                             took 0.000535 seconds
#   prepStrListTable                              took 0.000287 seconds
#   effectStrListTable                            took 0.000251 seconds
#   colorBoxPlotKeyPlot                           took 0.108384 seconds
#   germList2ColTable                             took 0.00035 seconds
#   progressTable                                 took 7.404565 seconds
# *** Generating plots ***
#   gramBarPlot                                   took 0.601356 seconds
#   progressBarPlot                               took 0.457262 seconds
#   progressBarPlot_sum                           took 0.001222 seconds
#   finalFitComparePlot                           took 0.12118 seconds
#   bestEstimateColorBoxPlot                      took 24.065576 seconds
#   bestEstimateTVDColorBoxPlot                   took 9.525681 seconds
#   bestEstimateColorScatterPlot                  took 9.37873 seconds
#   bestEstimateColorHistogram                    took 3.507419 seconds
#   progressTable_scl                             took 3.423892 seconds
#   progressBarPlot_scl                           took 0.278957 seconds
#   bestEstimateColorBoxPlot_scl                  took 7.89053 seconds
#   bestEstimateColorScatterPlot_scl              took 2.748029 seconds
#   bestEstimateColorHistogram_scl                took 1.145955 seconds
#   dataScalingColorBoxPlot                       took 0.184128 seconds
# *** Merging into template file ***
#   Rendering bestEstimateColorHistogram          took 2.506031 seconds
#   Rendering bestEstimateColorScatterPlot        took 1.648109 seconds
#   Rendering fiducialListTable                   took 0.002815 seconds
#   Rendering bestGatesetDecompTable              took 0.522111 seconds
#   Rendering bestGatesetGaugeOptParamsTable      took 0.002132 seconds
#   Rendering bestGatesetSpamVsTargetTable        took 0.005219 seconds
#   Rendering bestGatesetGatesBoxTable            took 1.003813 seconds
#   Rendering bestGatesetVsTargetTable            took 0.002159 seconds
#   Rendering bestGatesVsTargetTable_gv           took 0.006786 seconds
#   Rendering bestGatesVsTargetTable_gigerms      took 0.007076 seconds
#   Rendering bestGatesetSpamParametersTable      took 0.003088 seconds
#   Rendering finalFitComparePlot                 took 0.060359 seconds
#   Rendering bestGatesetErrGenBoxTable           took 3.695621 seconds
#   Rendering metadataTable                       took 0.005101 seconds
#   Rendering bestEstimateTVDColorBoxPlot         took 1.230202 seconds
#   Rendering metricSwitchboard_gi                took 6.4e-05 seconds
#   Rendering metricSwitchboard_gv                took 9.1e-05 seconds
#   Rendering singleMetricTable_gv                took 0.006859 seconds
#   Rendering dataScalingColorBoxPlot             took 0.087809 seconds
#   Rendering softwareEnvTable                    took 0.002504 seconds
#   Rendering profilerTable                       took 0.003603 seconds
#   Rendering progressBarPlot_scl                 took 0.062768 seconds
#   Rendering bestEstimateColorHistogram_scl      took 0.394999 seconds
#   Rendering bestGatesVsTargetTable_gi           took 0.006314 seconds
#   Rendering bestEstimateColorBoxPlot_scl        took 0.421577 seconds
#   Rendering bestGermsEvalTable                  took 0.137908 seconds
#   Rendering targetGatesBoxTable                 took 0.50151 seconds
#   Rendering bestGatesetEvalTable                took 0.036545 seconds
#   Rendering gramBarPlot                         took 0.178566 seconds
#   Rendering colorBoxPlotKeyPlot                 took 0.065759 seconds
#   Rendering progressTable                       took 0.013132 seconds
#   Rendering exampleTable                        took 0.061316 seconds
#   Rendering bestEstimateColorBoxPlot            took 2.839952 seconds
#   Rendering topSwitchboard                      took 0.000181 seconds
#   Rendering prepStrListTable                    took 0.00294 seconds
#   Rendering bestGatesVsTargetTable_sum          took 0.007983 seconds
#   Rendering datasetOverviewTable                took 0.00077 seconds
#   Rendering stdoutBlock                         took 0.001234 seconds
#   Rendering bestGatesetSpamBriefTable           took 1.033253 seconds
#   Rendering singleMetricTable_gi                took 0.006448 seconds
#   Rendering effectStrListTable                  took 0.002254 seconds
#   Rendering progressTable_scl                   took 0.005388 seconds
#   Rendering germList2ColTable                   took 0.004115 seconds
#   Rendering progressBarPlot_sum                 took 0.165609 seconds
#   Rendering maxLSwitchboard1                    took 0.000132 seconds
#   Rendering bestGatesVsTargetTable_gvgerms      took 0.01055 seconds
#   Rendering bestEstimateColorScatterPlot_scl    took 0.559236 seconds
#   Rendering progressBarPlot                     took 0.16226 seconds
#   Rendering bestGatesetChoiEvalTable            took 0.997834 seconds
#   Rendering targetSpamBriefTable                took 2.236622 seconds
# Output written to ../tutorial_files/gettingStartedReport directory
# *** Report Generation Complete!  Total time 104.725s ***

# %% [markdown]
# You can now open the file [../tutorial_files/gettingStartedReport/main.html](../tutorial_files/gettingStartedReport/main.html) in your browser (Firefox works best) to view the report.  **That's it!  You've just run GST!**
#
# In the cell above, `results` is a `Results` object, which is used to generate a HTML report.  For more information see the [Results object tutorial](../objects/advanced/Results.ipynb) and [report generation tutorial](../reporting/ReportGeneration.ipynb).

# %%
from IPython.display import IFrame

IFrame(src='../tutorial_files/gettingStartedReport/main.html', width=700, height=600)
# Out:
#         <iframe
#             width="700"
#             height="600"
#             src="../tutorial_files/gettingStartedReport/main.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
